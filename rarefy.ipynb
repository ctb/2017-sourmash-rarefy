# %%
# %matplotlib inline
from matplotlib import pyplot

# %%
import pandas

# %%
a = pandas.read_csv('ecoli-rare.csv')
b = pandas.read_csv('subsample.csv')
#c = pandas.read_csv('tara-100k.csv')

# %%
pyplot.plot(a.n, a.k, label='ecoli')
pyplot.plot(b.n, b.k, label='subsample')
pyplot.plot(b.n, b.known, label='subsample known')
#pyplot.plot(c.n, c.k, label='tara')
pyplot.legend(loc='upper left')

# %%
c
# Out:
#            n         k
# 0          0       0.0
# 1      10000    3922.6
# 2      20000    7716.2
# 3      30000   11374.4
# 4      40000   14961.8
# 5      50000   18420.0
# 6      60000   21779.2
# 7      70000   25056.4
# 8      80000   28280.4
# 9      90000   31474.6
# 10    100000   34504.4
# 11    110000   37586.2
# 12    120000   40522.8
# 13    130000   43530.8
# 14    140000   46319.0
# 15    150000   49160.6
# 16    160000   51921.8
# 17    170000   54698.8
# 18    180000   57329.0
# 19    190000   59992.0
# 20    200000   62575.4
# 21    210000   65199.4
# 22    220000   67672.8
# 23    230000   70300.6
# 24    240000   72645.4
# 25    250000   75126.2
# 26    260000   77612.8
# 27    270000   79876.0
# 28    280000   82356.4
# 29    290000   84685.2
# ..       ...       ...
# 348  3480000  483571.8
# 349  3490000  484441.2
# 350  3500000  485270.4
# 351  3510000  486178.2
# 352  3520000  487139.6
# 353  3530000  487927.0
# 354  3540000  488704.6
# 355  3550000  489516.8
# ...
